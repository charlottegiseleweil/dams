# %%
# import required modules
import os
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
# set directory paths
root = '../../..'
result_csv = os.path.join(root, 'results/results_validation_fasterRCNN-07-27.csv')

# %%
# create dataframe
result_df = pd.read_csv(result_csv)

# %%
# add results column for confidence threshold -- work in progress
def add_conf_result_col (df, iou_thres, conf_thres):
    df['tp'] = np.where((df.iou > iou_thres) & (df.confidence > conf_thres), 1, 0)
    df['fp'] = np.where(((df.iou <= iou_thres) | (df.confidence <= conf_thres)) | ((df.pred_bbox.notnull() & df.gt_bbox.isnull())), 1, 0)
    df['fn'] = np.where(((df.iou <= iou_thres) | (df.confidence <= conf_thres)) | ((df.pred_bbox.isnull() & df.gt_bbox.notnull())), 1, 0)
    df['result@IoU'+str(iou_thres)+'@conf'+str(conf_thres)] = detect_df.apply(
        lambda row: 'tp' if row.tp == 1 else 'fp+fn' if (row.fp == 1) & (row.fn == 1) else 'fp' if (row.fp == 1) else 'fn' if (row.fn == 1) else 'tn',
        axis=1
    )
    df = df.drop(['tp', 'fp', 'fn'], axis=1)
    return df

# %%
fp_fn_df = result_df[result_df['result@IoU0.05'] == 'fp+fn']
fp_only_df = fp_fn_df
fn_only_df = fp_fn_df
fp_only_df['result@IoU0.05'] = 'fp'
fn_only_df['result@IoU0.05'] = 'fn'
non_fp_fn_df = result_df[result_df['result@IoU0.05'] != 'fp+fn']
result_df_sparse = non_fp_fn_df.append(fp_only_df).append(fn_only_df)

#print(result_df_sparse.sort_values('img_id'))
# Out:
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(result_df_sparse.sort_values('img_id'))
# Out:
#                        img_id            gt_bbox              gt_format  \
# 4136  1000-1295_not_a_dam.txt                NaN  left/bottom/right/top
# 563                100007.txt  [262 280 351 333]  left/bottom/right/top
# 4081               100014.txt  [249 281 343 311]  left/bottom/right/top
# 4145               100022.txt  [ 73  89 149 134]  left/bottom/right/top
# 1346               100027.txt  [105 100 138 143]  left/bottom/right/top
# 2238               100032.txt  [ 14  78 194 130]  left/bottom/right/top
# 4034               100040.txt  [275 313 420 381]  left/bottom/right/top
# 200                100041.txt  [250 242 264 273]  left/bottom/right/top
# 1699               100048.txt  [208 242 352 319]  left/bottom/right/top
# 3992               100067.txt  [221 289 385 317]  left/bottom/right/top
# 2401               100072.txt  [124 154 256 226]  left/bottom/right/top
# 5622               100077.txt  [  4 142 347 211]  left/bottom/right/top
# 6295               100085.txt  [ 39 -67 201 308]  left/bottom/right/top
# 3798               100093.txt  [285 194 333 424]  left/bottom/right/top
# 2414               100096.txt  [106  51 138 193]  left/bottom/right/top
# 1558  1001-1250_not_a_dam.txt                NaN  left/bottom/right/top
# 1803               100105.txt  [189 142 216 262]  left/bottom/right/top
# 3184               100114.txt  [254 268 377 363]  left/bottom/right/top
# 48                 100115.txt  [ 10  67 136  80]  left/bottom/right/top
# 2542               100119.txt  [ 68  21 140 187]  left/bottom/right/top
# 45                 100120.txt  [112  89 224 247]  left/bottom/right/top
# 5346               100135.txt  [101  73 179 207]  left/bottom/right/top
# 5152               100144.txt  [291 304 381 368]  left/bottom/right/top
# 768                100147.txt  [281 314 382 348]  left/bottom/right/top
# 2482               100171.txt  [ 47  35 110 121]  left/bottom/right/top
# 3419               100181.txt  [ 28  61 224 191]  left/bottom/right/top
# 1103               100182.txt  [147 141 167 173]  left/bottom/right/top
# 2899               100194.txt  [211 174 279 316]  left/bottom/right/top
# 6461  1002-1263_not_a_dam.txt                NaN  left/bottom/right/top
# 2120  1002-1277_not_a_dam.txt                NaN  left/bottom/right/top
# ...                       ...                ...                    ...
# 2670                99870.txt  [289 275 310 323]  left/bottom/right/top
# 2854                99876.txt  [210 228 296 277]  left/bottom/right/top
# 2854                99876.txt  [210 228 296 277]  left/bottom/right/top
# 1056                99887.txt  [130 147 179 162]  left/bottom/right/top
# 1065                99899.txt  [233 236 272 268]  left/bottom/right/top
# 1065                99899.txt  [233 236 272 268]  left/bottom/right/top
# 1561   999-1277_not_a_dam.txt                NaN  left/bottom/right/top
# 885                   999.txt  [ 16 -38 300 355]  left/bottom/right/top
# 4380                99904.txt  [296 298 338 336]  left/bottom/right/top
# 3474                99909.txt  [198 259 347 286]  left/bottom/right/top
# 3474                99909.txt  [198 259 347 286]  left/bottom/right/top
# 4574                99911.txt  [307 314 332 324]  left/bottom/right/top
# 4430                99916.txt  [341 341 352 351]  left/bottom/right/top
# 4430                99916.txt  [341 341 352 351]  left/bottom/right/top
# 4677                99920.txt  [115 135 169 149]  left/bottom/right/top
# 4677                99920.txt  [115 135 169 149]  left/bottom/right/top
# 5298                99922.txt  [156 197 264 223]  left/bottom/right/top
# 248                 99932.txt  [ 66 113 192 145]  left/bottom/right/top
# 3954                99934.txt  [203 197 261 267]  left/bottom/right/top
# 4704                99939.txt  [167 189 237 214]  left/bottom/right/top
# 2241                99940.txt  [281 299 345 326]  left/bottom/right/top
# 2241                99940.txt  [281 299 345 326]  left/bottom/right/top
# 4549                99952.txt  [296 296 321 320]  left/bottom/right/top
# 4549                99952.txt  [296 296 321 320]  left/bottom/right/top
# 6271                99979.txt  [146 153 200 193]  left/bottom/right/top
# 80                  99980.txt  [309 326 385 367]  left/bottom/right/top
# 80                  99980.txt  [309 326 385 367]  left/bottom/right/top
# 6168                99981.txt  [256 215 298 339]  left/bottom/right/top
# 167                 99989.txt  [329 311 356 373]  left/bottom/right/top
# 1265                99998.txt  [214 278 386 322]  left/bottom/right/top
#
#               pred_bbox            pred_format  confidence   gt_size  \
# 4136  [200 137 184 150]  top/left/bottom/right      0.1211       NaN
# 563   [326 261 282 348]  top/left/bottom/right      0.9114    4717.0
# 4081  [300 262 291 286]  top/left/bottom/right      0.0602    2820.0
# 4145  [109  58  79 145]  top/left/bottom/right      0.7623    3420.0
# 1346  [145  99 101 137]  top/left/bottom/right      0.6955    1419.0
# 2238  [127  10  82 197]  top/left/bottom/right      0.9116    9360.0
# 4034  [356 276 308 364]  top/left/bottom/right      0.7044    9860.0
# 200   [275 248 238 265]  top/left/bottom/right      0.6317     434.0
# 1699  [322 206 239 359]  top/left/bottom/right      0.8819   11088.0
# 4549  [388 183 289 221]  top/left/bottom/right      0.8441     600.0
# 4549  [388 183 289 221]  top/left/bottom/right      0.8441     600.0
# 6271  [196 143 148 202]  top/left/bottom/right      0.8135    2160.0
# 80    [255 206 210 263]  top/left/bottom/right      0.7285    3116.0
# 80    [255 206 210 263]  top/left/bottom/right      0.7285    3116.0
# 6168  [369 269 212 327]  top/left/bottom/right      0.2423    5208.0
# 167   [374 329 314 359]  top/left/bottom/right      0.8369    1674.0
# 1265  [323 213 275 385]  top/left/bottom/right      0.8560    7568.0
#
#            iou result@IoU0.0 result@IoU0.05 result@IoU0.1 result@IoU0.2  \
# 4136       NaN            fp             fp            fp            fp
# 563   0.794791            tp             tp            tp            tp
# 4081  0.076596            tp             tp         fp+fn         fp+fn
# 4145  0.313725            tp             tp            tp            tp
# 1346  0.769319            tp             tp            tp            tp
# 2238  0.837209            tp             tp            tp            tp
# 4034  0.367379            tp             tp            tp            tp
# 200   0.689984            tp             tp            tp            tp
# 1699  0.873140            tp             tp            tp            tp
# 3992  0.625159            tp             tp            tp            tp
# 2401  0.709785            tp             tp            tp            tp
# 5622  0.271800            tp             tp            tp            tp
# 6295  0.734012            tp             tp            tp            tp
# 3798  0.617940            tp             tp            tp            tp
# 2414  0.602173            tp             tp            tp            tp
# 1558       NaN            fp             fp            fp            fp
# 1803  0.317393            tp             tp            tp            tp
# 3184  0.866591            tp             tp            tp            tp
# 48    0.455000            tp             tp            tp            tp
# 2542  0.776224            tp             tp            tp            tp
# 45    0.702904            tp             tp            tp            tp
# 5346  0.771372            tp             tp            tp            tp
# 5152  0.776389            tp             tp            tp            tp
# 768   0.805310            tp             tp            tp            tp
# 2482  0.599852            tp             tp            tp            tp
# 3419  0.803797            tp             tp            tp            tp
# 1103  0.070892            tp             tp         fp+fn         fp+fn
# 2899  0.267502            tp             tp            tp            tp
# 6461       NaN            fp             fp            fp            fp
# 2120       NaN            fp             fp            fp            fp
# ...        ...           ...            ...           ...           ...
# 2670  0.719912            tp             tp            tp            tp
# 2854  0.000000         fp+fn             fn         fp+fn         fp+fn
# 2854  0.000000         fp+fn             fn         fp+fn         fp+fn
# 1056  0.507054            tp             tp            tp            tp
# 1065  0.000000         fp+fn             fn         fp+fn         fp+fn
# 1065  0.000000         fp+fn             fn         fp+fn         fp+fn
# 1561       NaN            fp             fp            fp            fp
# 885   0.632250            tp             tp            tp            tp
# 4380  0.852564            tp             tp            tp            tp
# 3474  0.000000         fp+fn             fn         fp+fn         fp+fn
# 3474  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4574  0.220000            tp             tp            tp            tp
# 4430  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4430  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4677  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4677  0.000000         fp+fn             fn         fp+fn         fp+fn
# 5298  0.703539            tp             tp            tp            tp
# 248   0.860140            tp             tp            tp            tp
# 3954  0.050256            tp             tp         fp+fn         fp+fn
# 4704  0.710227            tp             tp            tp            tp
# 2241  0.000000         fp+fn             fn         fp+fn         fp+fn
# 2241  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4549  0.000000         fp+fn             fn         fp+fn         fp+fn
# 4549  0.000000         fp+fn             fn         fp+fn         fp+fn
# 6271  0.762712            tp             tp            tp            tp
# 80    0.000000         fp+fn             fn         fp+fn         fp+fn
# 80    0.000000         fp+fn             fn         fp+fn         fp+fn
# 6168  0.335510            tp             tp            tp            tp
# 167   0.846890            tp             tp            tp            tp
# 1265  0.906506            tp             tp            tp            tp
#
#      result@IoU0.5
# 4136            fp
# 563             tp
# 4081         fp+fn
# 4145         fp+fn
# 1346            tp
# 2238            tp
# 4034         fp+fn
# 200             tp
# 1699            tp
# 3992            tp
# 2401            tp
# 5622         fp+fn
# 6295            tp
# 3798            tp
# 2414            tp
# 1558            fp
# 1803         fp+fn
# 3184            tp
# 48           fp+fn
# 2542            tp
# 45              tp
# 5346            tp
# 5152            tp
# 768             tp
# 2482            tp
# 3419            tp
# 1103         fp+fn
# 2899         fp+fn
# 6461            fp
# 2120            fp
# ...            ...
# 2670            tp
# 2854         fp+fn
# 2854         fp+fn
# 1056            tp
# 1065         fp+fn
# 1065         fp+fn
# 1561            fp
# 885             tp
# 4380            tp
# 3474         fp+fn
# 3474         fp+fn
# 4574         fp+fn
# 4430         fp+fn
# 4430         fp+fn
# 4677         fp+fn
# 4677         fp+fn
# 5298            tp
# 248             tp
# 3954         fp+fn
# 4704            tp
# 2241         fp+fn
# 2241         fp+fn
# 4549         fp+fn
# 4549         fp+fn
# 6271            tp
# 80           fp+fn
# 80           fp+fn
# 6168         fp+fn
# 167             tp
# 1265            tp
#
# [8129 rows x 13 columns]

# %%
def get_recall_score (result_csv, iou_thres, conf_thres):

    # gather y_true and y_scores
    real_conf = result_df[result_df['confidence'] > conf_thres]
    y_true = pd.Series(real_conf['gt_bbox'].notnull() == True).values
    y_true = np.where(y_true == True, 1, y_true)
    y_pred = pd.Series(real_conf['result@IoU'+str(iou_thres)] == 'tp').values
    ratio = sum(y_pred)/sum(y_true)
    recall_score = metrics.recall_score(y_true, y_pred)
    return ratio, recall_score

# %%
ratio, recall_score = get_recall_score(result_df, 0.5, 0.0)
print(ratio)
print(recall_score)
# Out:
# 0.46489832007073384
# 0.46489832007073384

# %%
def get_mAP (result_df, iou_thres, conf_thres):
    
    # gather y_true and y_scores
    real_conf = result_df[result_df['confidence'] > conf_thres]
    y_true = pd.Series(real_conf['gt_bbox'].notnull() == True).values
    #y_true = pd.Series((real_conf['result@IoU'+str(iou_thres)] == 'tp')).values
    print(sum(y_true))
    y_true = np.where(y_true == True, 1, y_true)
    y_scores = real_conf['confidence'].values.astype(float)
    
    # calculate average precision, precision, recall, and thresholds
    ap = metrics.average_precision_score(y_true, y_scores) 
    
    return ap

# args df, iou_thres, conf_thres

# %%
mAP = get_mAP(result_df, 0.05, 0.0)
print(mAP)
# Out:
# 5655
# 0.9769034728679117
